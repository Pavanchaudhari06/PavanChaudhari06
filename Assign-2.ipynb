# %% [markdown]
# # Assignment ---> 2

# %%
 # working with list

# %%
l = [1,2,3,4,5,6]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append("7")

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, '7']

# %%
l.insert(3, 2)

# %%
l
# Out:
# [1, 2, 3, 2, 4, 5, 6, '7']

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6, '7'}

# %%
# working with tuple

# %%
a = ("red","yellow","green","white","black")

# %%
a
# Out:
# ('red', 'yellow', 'green', 'white', 'black')

# %%
a[3] = "pink"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 a[3] = "pink"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Explenation :- tuple is Immutable that means we cant make changes in it after the creation

# %%
a
# Out:
# ('red', 'yellow', 'green', 'white', 'black')

# %%
list(a)
# Out:
# ['red', 'yellow', 'green', 'white', 'black']

# %%
a = list(a)

# %%
a
# Out:
# ['red', 'yellow', 'green', 'white', 'black']

# %%
a[3] = "pink"

# %%
a
# Out:
# ['red', 'yellow', 'green', 'pink', 'black']

# %%
a = tuple(a)

# %%
a
# Out:
# ('red', 'yellow', 'green', 'pink', 'black')

# %%
# working with set

# %%
a = {10,20,30,40}
b = {30,40,50,60}

# %%
a.union(b)
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
a.intersection(b)
# Out:
# {30, 40}

# %%
a.difference(b)
# Out:
# {10, 20}

# %%
b.difference(a)
# Out:
# {50, 60}

# %%
a.add(42)

# %%
a
# Out:
# {10, 20, 30, 40, 42}

# %%
a.remove(42)

# %%
a
# Out:
# {10, 20, 30, 40}

# %%
library = { "history" : 5,"python" : 3,"c" : 6}
library["history"] = library["history"] - 1
print("after borowwing", library)
library["math"] = 1
print("after adding", library)
# Out:
# after borowwing {'history': 4, 'python': 3, 'c': 6}
# after adding {'history': 4, 'python': 3, 'c': 6, 'math': 1}
