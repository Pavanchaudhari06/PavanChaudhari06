# %%
l = [10,20,30]

# %%
for i in l:
    print("hello")
# Out:
# hello
# hello
# hello

# %%
list(range(1,10,2))
# Out:
# [1, 3, 5, 7, 9]

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,6):
   print(i * '$')
# Out:
# $
# $$
# $$$
# $$$$
# $$$$$

# %%
n =int(input("Enter value"))
sum_n = 0

for i in range(1,n + 1):
    sum_n = sum_n + i
    
print("sum of first",n, "natural number is", sum_n)
# Out:
# Enter value 5
# sum of first 5 natural number is 15

# %%
a =int(input("Enter value"))
       
for i in range(11,0,-1):
    print("munber",a,"X",i,"=",a * i)
# Out:
# Enter value 5
# munber 5 X 11 = 55
# munber 5 X 10 = 50
# munber 5 X 9 = 45
# munber 5 X 8 = 40
# munber 5 X 7 = 35
# munber 5 X 6 = 30
# munber 5 X 5 = 25
# munber 5 X 4 = 20
# munber 5 X 3 = 15
# munber 5 X 2 = 10
# munber 5 X 1 = 5

# %%
for i in range(1,11):
    print("Squre of",i,"is",i * i * i)
# Out:
# Squre of 1 is 1
# Squre of 2 is 8
# Squre of 3 is 27
# Squre of 4 is 64
# Squre of 5 is 125
# Squre of 6 is 216
# Squre of 7 is 343
# Squre of 8 is 512
# Squre of 9 is 729
# Squre of 10 is 1000

# %%
a =int(input("Enter value"))
for i in range(1,11):
    print(a,"/",i,"=",i / i)
# Out:
# Enter value 5
# 5 / 1 = 1.0
# 5 / 2 = 1.0
# 5 / 3 = 1.0
# 5 / 4 = 1.0
# 5 / 5 = 1.0
# 5 / 6 = 1.0
# 5 / 7 = 1.0
# 5 / 8 = 1.0
# 5 / 9 = 1.0
# 5 / 10 = 1.0

# %%
a = int(input("Enetr value"))
for i in range(1,11):
   print(a,"+",i,"=",a+i)
# Out:
# Enetr value 5
# 5 + 1 = 6
# 5 + 2 = 7
# 5 + 3 = 8
# 5 + 4 = 9
# 5 + 5 = 10
# 5 + 6 = 11
# 5 + 7 = 12
# 5 + 8 = 13
# 5 + 9 = 14
# 5 + 10 = 15

# %%
a =int(input("Enter Value"))
for i in range(1,6):
  print(a * i )
# Out:
# Enter Value 2
# 2
# 4
# 6
# 8
# 10

# %%
sum = 0
for i in range(1,6):
      print(i)
      sum = sum + i
print("sum ",sum)
# Out:
# 1
# 2
# 3
# 4
# 5
# sum  15

# %%
for i in range(1,6):
    for j in range(i):
        print(i, end ="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
n = 5

for i in range(1, n + 1):
    for j in range(i):
        print(i, end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(1, 6):
    for j in range(i):
        print(i, end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
