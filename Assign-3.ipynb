# %% [markdown]
# # Assignment ----> 3

# %%
# working with conditons

# %%
# for checking vote eligibility

a =float(input("Enter age"))
if a > 18:
    print("You are Eligible For Vote")
else:
    print("You are not eligible for Vote")
# Out:
# Enter age 10
# You are not eligible for Vote

# %%
# for positive and negative number

a =float(input("Enter Number"))
  a > 0:
    print("Number is Positive")
else:
    print("Number is Negative")
# Out:
# Enter Number -10
# Number is Negative

# %%
# for grade for marks 

a =float(input("enter Marks"))
if a >= 90 and a <= 100:
       print("A+")
elif a >= 80 and a <= 90:
    print("B+")
elif a >= 70 and a <= 80:
    print("c+")
else: 
    print("Fail")
# Out:
# enter Marks 69
# Fail

# %%
# for leap year 

a =int(input("Enter year"))
if (a % 4 == 0 and a % 100 != 0) or (a % 400 == 0):
    print("Year is leap year")
else:
    print("its not")
# Out:
# Enter year 2024
# Year is leap year

# %%
# for comparing three numbers 

a =int(input("Enter 1st no"))
b =int(input("Enter 2nd no"))
c =int(input("Enter 3rd no"))

if a > b:
    print("1st number is largest number")
if b > c:
    print("2nd Number is largest number")
if c > a:
    print("3rd Number is largest number")
else:
    print("invalid")
# Out:
# Enter 1st no 5
# Enter 2nd no 1
# Enter 3rd no 2
# 1st number is largest number
# invalid

# %%
# for discount calculator

a = int(input("Enter value"))
b = a * 20 / 100
if a >= 100 :
    print("Get discount of ", b)
elif a >= 50 and a <= 100:
    print("Get discount of ", b)
else:
    print("no discount")
# Out:
# Enter value 42
# no discount
