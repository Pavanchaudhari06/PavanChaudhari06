# %%
data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]

# %%
data
# Out:
# ['a', 'b', ['c', ['d', 'e', 'target'], 'f'], 'g']

# %%
print(data[2][1][2])
# Out:
# target

# %%
print(data[2][1][2])
# Out:
# target

# %%
colors = ["red", "blue"]

# %%
colors
# Out:
# ['red', 'blue']

# %%
colors.append(["green","yellow"])

# %%
colors
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %%
colors.extend(["green","yellow"])

# %%
colors
# Out:
# ['red', 'blue', ['green', 'yellow'], ['green', 'yellow'], 'green', 'yellow']

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[2][2]
# Out:
# 9

# %%
print(matrix[1][2])
# Out:
# 6

# %%
nums = [10, 20, 40]

# %%
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40]

# %%
mixed = [1, "Python", [True, False]]

# %%
mixed[2][1] = None

# %%
mixed
# Out:
# [1, 'Python', [True, None]]

# %%
mixed[1]
# Out:
# 'Python'

# %%
print(mixed[2][1])
# Out:
# None

# %%
nested = [1, [2, 3, [4, 5, 6]], 7]

# %%
print(nested[1][0])
# Out:
# 2

# %%
nested[1][2]
# Out:
# [4, 5, 6]

# %%
nested[1][2][1]
# Out:
# 5

# %%
matrix = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
matrix[1]
# Out:
# [40, 50, 60]

# %%
matrix[2][2]
# Out:
# 90

# %%
matrix[1][0]
# Out:
# 40

# %%
fruits = ['apple', 'banana']

# %%
fruits.extend(['kivi','mango'])

# %%
fruits
# Out:
# ['apple', 'banana', 'kivi', 'mango']

# %%
nums = [10, 20, 40, 50]

# %%
nums.insert(2,30)

# %%
nums
# Out:
# [10, 20, 30, 40, 50]
