# %%
# assignment again 1-->

# %%
name = 'pavan'

# %%
name
# Out:
# 'pavan'

# %%
age = 21

# %%
GPA = 7.8

# %%
type(GPA)
# Out:
# float

# %%
subjects = 'history,geografy,math'

# %%
subjects
# Out:
# 'history,geografy,math'

# %%
age_months = age * 12

# %%
print("age in months",age_months)
# Out:
# age in months 252

# %%
sentence = ("student name = "+ name + ",Age = " + str(age) + ",GPA =" + str(GPA) +",Subjects = " +subjects)

# %%
sentence
# Out:
# 'student name = pavan,Age = 21,GPA =7.8,Subjects = history,geografy,math'

# %%
# conversion practice

# %%
int(GPA)
# Out:
# 7
