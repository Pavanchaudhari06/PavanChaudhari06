# %%
#slicing list questions -->

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[2:5]
# Out:
# [30, 40, 50]

# %%
l[:4]
# Out:
# [10, 20, 30, 40]

# %%
l[5:]
# Out:
# [60, 70, 80]

# %%
l[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
l[-1]
# Out:
# 80

# %%
l[:-1]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
l[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[-4:-1]
# Out:
# [50, 60, 70]

# %%
l[6:1:-2]
# Out:
# [70, 50, 30]

# %%
l[5:]
# Out:
# [60, 70, 80]

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][1]
# Out:
# 200

# %%
nested[2][2][1]
# Out:
# 400

# %%
nested[2][1] = 250

# %%
nested
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
nested[0:]
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
nested[0:3]
# Out:
# [1, 2, [100, 250, [300, 400]]]

# %%
nested[2][0:2]
# Out:
# [100, 250]

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %%
data[-1][-1]
# Out:
# 9

# %%
z = [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]
