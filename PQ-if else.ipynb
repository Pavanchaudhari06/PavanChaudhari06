# %%
# for 

a =int(input("Ebter unit number"))
if a > 500 :
    bill = a * 8
elif a >= 200:
    bill = a * 5
else:
    bill = a * 2

print("Electricity bill is", bill)
# Out:
# Ebter unit number 500
# Electricity bill is 2500

# %%
# for charector

a =str(input("Enter Charector"))
if a == ("a","e","i","o","u","A","E","I","O","U"):
   print("charector is Wovel")
else:
   print("charector is consonant")
# Out:
# Enter Charector b
# charector is consonant

# %%
a =int(input("Enter Salary"))
if a > 50000:
    s = a * 15 / 100
elif a >= 30000:
    s = a * 10 / 100
else:
    s = a * 5 / 100

print("Salary with bonus", s + a)
# Out:
# Enter Salary 45000
# Salary with bonus 49500.0
