# %% [markdown]
# # Pavan Assignment ----> 1

# %%
# Variable Manipulation

# %%
name = "Pavan"
age = 18
GPA = 9.4
Subjects = "History, Jeography, python"

# %%
age
# Out:
# 18

# %%
a = age * 12
print("Age is ", a,"Months")
# Out:
# Age is  216 Months

# %%
print("Student name is",name , "he is ",age,"Year old", " his Gpa is",GPA, " his choosen Subjects are ",Subjects)
# Out:
# Student name is Pavan he is  18 Year old  his Gpa is 9.4  his choosen Subjects are  History, Jeography, python

# %%
# type converstion

# %%
int(GPA)
# Out:
# 9

# %% [raw]
# Explanatin :- in the question their is asked to convert to Float Value in the Integer
#               So Python integers cannot store decimal numbers it is used to store whole number
#               so in the conversion Float value = 9 becomes Integer = 9 using int()
