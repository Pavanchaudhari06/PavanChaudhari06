# %%
# Pavan Assignment --> 1

# %%
# convert one data type to another

# %%
num = 5

# %%
num
# Out:
# 5

# %%
str(num)
# Out:
# '5'

# %%
name = 'Pavan'

# %%
name
# Out:
# 'Pavan'

# %%
float(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 float(name)
#
# ValueError: could not convert string to float: 'Pavan'

# %%
float(num)
# Out:
# 5.0

# %%
# diffrence btw = $ ==

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a == 6
# Out:
# False

# %%
a ==5
# Out:
# True

# %%
# module operater (%)

# %%
10 % 3
# Out:
# 1

# %%
x = 6

# %%
x % 2 == 0
# Out:
# True

# %%
# output of-->

# %%
'hello' * 3
# Out:
# 'hellohellohello'

# %%
# Concatination of String

# %%
first_name = 'Pavan'

# %%
last_name = 'Chaudhari'

# %%
full_name = first_name + " " + last_name

# %%
print(full_name)
# Out:
# Pavan Chaudhari
